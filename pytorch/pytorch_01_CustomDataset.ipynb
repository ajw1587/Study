# %%
from google.colab import drive
drive.mount('/content/gdrive/')

import torch
import torch.nn as nn
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

# Dataset 상속
class CustomDataset(Dataset):
  # Dataset 상속
  def __init__(self):
    self.x_data = [[73, 80, 75],
                   [93, 88, 93],
                   [89, 91, 90],
                   [96, 98, 100],
                   [73, 66, 70]]
    self.y_data = [[152], [185], [180], [196], [142]]

  # 총 데이터의 개수를 리턴
  def __len__(self):
    return len(self.x_data)

  # index를 입력받아 그에 맵핑되는 입출력 데이터를 파이토치의 Tensor 형태로 리턴
  def __getitem__(self, idx):
    x = torch.FloatTensor(self.x_data[idx])
    y = torch.FloatTensor(self.y_data[idx])
    return x, y

dataset = CustomDataset()
dataloader = DataLoader(dataset, batch_size = 2, shuffle = True)

model = torch.nn.Linear(3, 1)
optimizer = torch.optim.SGD(model.parameters(), lr = 1e-5)

nb_epochs = 20
for epoch in range(nb_epochs + 1):
  for batch_idx, samples in enumerate(dataloader):
    x_train, y_train = samples

    prediction = model(x_train)

    cost = F.mse_loss(prediction, y_train)

    optimizer.zero_grad()
    cost.backward()
    optimizer.step()

    print('Epoch {:4d}/{} Batch {}/{} Cost: {:.6f}'.format(
    epoch, nb_epochs, batch_idx+1, len(dataloader),
    cost.item()
    ))
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).
# Epoch    0/20 Batch 1/3 Cost: 100671.906250
# Epoch    0/20 Batch 2/3 Cost: 22705.345703
# Epoch    0/20 Batch 3/3 Cost: 5772.125000
# Epoch    1/20 Batch 1/3 Cost: 3123.380371
# Epoch    1/20 Batch 2/3 Cost: 1144.210449
# Epoch    1/20 Batch 3/3 Cost: 195.369034
# Epoch    2/20 Batch 1/3 Cost: 95.125496
# Epoch    2/20 Batch 2/3 Cost: 56.706017
# Epoch    2/20 Batch 3/3 Cost: 6.219139
# Epoch    3/20 Batch 1/3 Cost: 5.750220
# Epoch    3/20 Batch 2/3 Cost: 3.922917
# Epoch    3/20 Batch 3/3 Cost: 0.137134
# Epoch    4/20 Batch 1/3 Cost: 3.006507
# Epoch    4/20 Batch 2/3 Cost: 1.057625
# Epoch    4/20 Batch 3/3 Cost: 0.038159
# Epoch    5/20 Batch 1/3 Cost: 0.198755
# Epoch    5/20 Batch 2/3 Cost: 2.767120
# Epoch    5/20 Batch 3/3 Cost: 1.513077
# Epoch    6/20 Batch 1/3 Cost: 0.949847
# Epoch    6/20 Batch 2/3 Cost: 2.621991
# Epoch    6/20 Batch 3/3 Cost: 1.053085
# Epoch    7/20 Batch 1/3 Cost: 2.579050
# Epoch    7/20 Batch 2/3 Cost: 3.138982
# Epoch    7/20 Batch 3/3 Cost: 0.422333
# Epoch    8/20 Batch 1/3 Cost: 0.464219
# Epoch    8/20 Batch 2/3 Cost: 1.988983
# Epoch    8/20 Batch 3/3 Cost: 2.739172
# Epoch    9/20 Batch 1/3 Cost: 2.905246
# Epoch    9/20 Batch 2/3 Cost: 0.879684
# Epoch    9/20 Batch 3/3 Cost: 0.698358
# Epoch   10/20 Batch 1/3 Cost: 0.384641
# Epoch   10/20 Batch 2/3 Cost: 1.368932
# Epoch   10/20 Batch 3/3 Cost: 4.322854
# Epoch   11/20 Batch 1/3 Cost: 1.353631
# Epoch   11/20 Batch 2/3 Cost: 1.141654
# Epoch   11/20 Batch 3/3 Cost: 2.941370
# Epoch   12/20 Batch 1/3 Cost: 3.812238
# Epoch   12/20 Batch 2/3 Cost: 0.750634
# Epoch   12/20 Batch 3/3 Cost: 1.439663
# Epoch   13/20 Batch 1/3 Cost: 0.181476
# Epoch   13/20 Batch 2/3 Cost: 4.762962
# Epoch   13/20 Batch 3/3 Cost: 0.885671
# Epoch   14/20 Batch 1/3 Cost: 0.437548
# Epoch   14/20 Batch 2/3 Cost: 3.995691
# Epoch   14/20 Batch 3/3 Cost: 1.141131
# Epoch   15/20 Batch 1/3 Cost: 0.830046
# Epoch   15/20 Batch 2/3 Cost: 2.597769
# Epoch   15/20 Batch 3/3 Cost: 0.716505
# Epoch   16/20 Batch 1/3 Cost: 2.351342
# Epoch   16/20 Batch 2/3 Cost: 0.841518
# Epoch   16/20 Batch 3/3 Cost: 1.884504
# Epoch   17/20 Batch 1/3 Cost: 2.847472
# Epoch   17/20 Batch 2/3 Cost: 0.803643
# Epoch   17/20 Batch 3/3 Cost: 1.822764
# Epoch   18/20 Batch 1/3 Cost: 1.590523
# Epoch   18/20 Batch 2/3 Cost: 2.379820
# Epoch   18/20 Batch 3/3 Cost: 0.699276
# Epoch   19/20 Batch 1/3 Cost: 0.986790
# Epoch   19/20 Batch 2/3 Cost: 2.591121
# Epoch   19/20 Batch 3/3 Cost: 0.650349
# Epoch   20/20 Batch 1/3 Cost: 1.092418
# Epoch   20/20 Batch 2/3 Cost: 1.984611
# Epoch   20/20 Batch 3/3 Cost: 2.261413
